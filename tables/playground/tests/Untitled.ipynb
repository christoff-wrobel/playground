# %%
# importing module
import sys
# appending a path
sys.path.append('C:/Users/Christoff Wrobel/OneDrive/Desktop/Software Entwicklung/PycharmProjects/playground/')

from modules.tableTool import TableTool
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [25], line 6
#       3 # appending a path
#       4 sys.path.append('C:/Users/Christoff Wrobel/OneDrive/Desktop/Software Entwicklung/PycharmProjects/playground/')
# ----> 6 from modules.tableTool import TableTool
#
# File ~\OneDrive\Desktop\Software Entwicklung\PycharmProjects\playground\tests\..\modules\tableTool.py:4
#       2 import pandas as pd
#       3 import math
# ----> 4 from table import Table
#       5 from abc import ABC
#       7 class TableTool(ABC):
#
# ImportError: cannot import name 'Table' from 'table' (C:\Users\Christoff Wrobel\OneDrive\Desktop\Software Entwicklung\PycharmProjects\playground\tests\table.py)
